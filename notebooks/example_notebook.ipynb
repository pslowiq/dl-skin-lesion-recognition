# %%
dataset = catalog.load('HAM10000')
# Out:
# [04/07/23 17:59:53] INFO     Loading data from 'HAM10000' (PartitionedDataSet)...               ]8;id=125293;file:///home/pslowiq/programs/pdl2023/dl-skin-lesion-recognition/env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=965891;file:///home/pslowiq/programs/pdl2023/dl-skin-lesion-recognition/env/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
from IPython.display import display
from PIL import Image
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=7, figsize=(25,25))

for j in range(7):        
        axes[j].imshow(dataset[list(dataset.keys())[j*22]]())
